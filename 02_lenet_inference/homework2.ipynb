# %% [markdown]
# # HW2: Model Inference of the Pretrained LeNet

# %% [markdown]
# <font color='red'>Name: 梁謙行 Student ID: 110061644 </font>

# %% [markdown]
# ## 1. High-level Function Implementation for Each Layer
# Implement a high-level functional model for each layer of the CNN, including convolution, pooling, and
# fully-connected layer with 8-bit quantization of the input activations, output activations, and weights accordingly.
# * Learn how to use [Numba](https://numba.pydata.org/) to accelerate python functions
# * Fill in the TODOs in `functional.py` of `nnutils`.
#     * You must consider `psum_range = (lower_bound, upper_bound)` which controls the precision of partial sums.
#     * `psum_record_list` will be used in *2. Bit-width of Partial Sums*, so you may leave it alone for now.
#
# ### 1.1 Pass all Unit Tests of OpTestCase in `nnunittest.py`.
# First, use 32-bit signed integers for the partial sums to pass the unit tests. The accumulation of activations is limited to 32 bits in convolution and fully-connected layers. Clamp the value if it exceeds the minimum or maximum values of the 32-bit signed number.
#
# Note that you should implement convolution layers, fully-connected layers, and max-pooling layers with "nested loops" by yourself. You are not allowed to use existing functions (e.g., `conv2d` in `numpy` or `pytorch`). Or you will not get any credits. Raise questions when in doubt.
#
# There are eight unit tests you need to pass. If you intend to run part of them, follow the steps:
# ```
# tests = ['test_C1', 'test_C3']
# suite = unittest.TestSuite(map(nnunittest.OpTestCase, tests))
# ```

# %%
#!pip install numba==0.55.1
# Out:
# Collecting numba==0.55.1
#   Downloading numba-0.55.1-1-cp37-cp37m-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 8.6 MB/s
# Collecting llvmlite<0.39,>=0.38.0rc1
#   Downloading llvmlite-0.38.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
#      |████████████████████████████████| 34.5 MB 12 kB/s
# Requirement already satisfied: numpy<1.22,>=1.18 in /usr/local/lib/python3.7/dist-packages (from numba==0.55.1) (1.21.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba==0.55.1) (57.4.0)
# Installing collected packages: llvmlite, numba
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.34.0
#     Uninstalling llvmlite-0.34.0:
#       Successfully uninstalled llvmlite-0.34.0
#   Attempting uninstall: numba
#     Found existing installation: numba 0.51.2
#     Uninstalling numba-0.51.2:
#       Successfully uninstalled numba-0.51.2
# Successfully installed llvmlite-0.38.0 numba-0.55.1

# %%
# !unzip parameters.zip
# Out:
# Archive:  parameters.zip
#   inflating: activations/img0/input.csv
#   inflating: activations/img0/output.csv
#   inflating: activations/img0/c1/input.csv
#   inflating: activations/img0/c1/output.csv
#   inflating: activations/img0/s2/input.csv
#   inflating: activations/img0/s2/output.csv
#   inflating: activations/img0/c3/input.csv
#   inflating: activations/img0/c3/output.csv
#   inflating: activations/img0/s4/input.csv
#   inflating: activations/img0/s4/output.csv
#   inflating: activations/img0/c5/input.csv
#   inflating: activations/img0/c5/output.csv
#   inflating: activations/img0/f6/input.csv
#   inflating: activations/img0/f6/output.csv
#   inflating: activations/img0/output/input.csv
#   inflating: activations/img0/output/output.csv
#   inflating: activations/img1/input.csv
#   inflating: activations/img1/output.csv
#   inflating: activations/img1/c1/input.csv
#   inflating: activations/img1/c1/output.csv
#   inflating: activations/img1/s2/input.csv
#   inflating: activations/img1/s2/output.csv
#   inflating: activations/img1/c3/input.csv
#   inflating: activations/img1/c3/output.csv
#   inflating: activations/img1/s4/input.csv
#   inflating: activations/img1/s4/output.csv
#   inflating: activations/img1/c5/input.csv
#   inflating: activations/img1/c5/output.csv
#   inflating: activations/img1/f6/input.csv
#   inflating: activations/img1/f6/output.csv
#   inflating: activations/img1/output/input.csv
#   inflating: activations/img1/output/output.csv
#   inflating: activations/img2/input.csv
#   inflating: activations/img2/output.csv
#   inflating: activations/img2/c1/input.csv
#   inflating: activations/img2/c1/output.csv
#   inflating: activations/img2/s2/input.csv
#   inflating: activations/img2/s2/output.csv
#   inflating: activations/img2/c3/input.csv
#   inflating: activations/img2/c3/output.csv
#   inflating: activations/img2/s4/input.csv
#   inflating: activations/img2/s4/output.csv
#   inflating: activations/img2/c5/input.csv
#   inflating: activations/img2/c5/output.csv
#   inflating: activations/img2/f6/input.csv
#   inflating: activations/img2/f6/output.csv
#   inflating: activations/img2/output/input.csv
#   inflating: activations/img2/output/output.csv
#   inflating: activations/img3/input.csv
#   inflating: activations/img3/output.csv
#   inflating: activations/img3/c1/input.csv
#   inflating: activations/img3/c1/output.csv
#   inflating: activations/img3/s2/input.csv
#   inflating: activations/img3/s2/output.csv
#   inflating: activations/img3/c3/input.csv
#   inflating: activations/img3/c3/output.csv
#   inflating: activations/img3/s4/input.csv
#   inflating: activations/img3/s4/output.csv
#   inflating: activations/img3/c5/input.csv
#   inflating: activations/img3/c5/output.csv
#   inflating: activations/img3/f6/input.csv
#   inflating: activations/img3/f6/output.csv
#   inflating: activations/img3/output/input.csv
#   inflating: activations/img3/output/output.csv
#   inflating: activations/img4/input.csv
#   inflating: activations/img4/output.csv
#   inflating: activations/img4/c1/input.csv
#   inflating: activations/img4/c1/output.csv
#   inflating: activations/img4/s2/input.csv
#   inflating: activations/img4/s2/output.csv
#   inflating: activations/img4/c3/input.csv
#   inflating: activations/img4/c3/output.csv
#   inflating: activations/img4/s4/input.csv
#   inflating: activations/img4/s4/output.csv
#   inflating: activations/img4/c5/input.csv
#   inflating: activations/img4/c5/output.csv
#   inflating: activations/img4/f6/input.csv
#   inflating: activations/img4/f6/output.csv
#   inflating: activations/img4/output/input.csv
#   inflating: activations/img4/output/output.csv
#   inflating: activations/img5/input.csv
#   inflating: activations/img5/output.csv
#   inflating: activations/img5/c1/input.csv
#   inflating: activations/img5/c1/output.csv
#   inflating: activations/img5/s2/input.csv
#   inflating: activations/img5/s2/output.csv
#   inflating: activations/img5/c3/input.csv
#   inflating: activations/img5/c3/output.csv
#   inflating: activations/img5/s4/input.csv
#   inflating: activations/img5/s4/output.csv
#   inflating: activations/img5/c5/input.csv
#   inflating: activations/img5/c5/output.csv
#   inflating: activations/img5/f6/input.csv
#   inflating: activations/img5/f6/output.csv
#   inflating: activations/img5/output/input.csv
#   inflating: activations/img5/output/output.csv
#   inflating: activations/img6/input.csv
#   inflating: activations/img6/output.csv
#   inflating: activations/img6/c1/input.csv
#   inflating: activations/img6/c1/output.csv
#   inflating: activations/img6/s2/input.csv
#   inflating: activations/img6/s2/output.csv
#   inflating: activations/img6/c3/input.csv
#   inflating: activations/img6/c3/output.csv
#   inflating: activations/img6/s4/input.csv
#   inflating: activations/img6/s4/output.csv
#   inflating: activations/img6/c5/input.csv
#   inflating: activations/img6/c5/output.csv
#   inflating: activations/img6/f6/input.csv
#   inflating: activations/img6/f6/output.csv
#   inflating: activations/img6/output/input.csv
#   inflating: activations/img6/output/output.csv
#   inflating: activations/img7/input.csv
#   inflating: activations/img7/output.csv
#   inflating: activations/img7/c1/input.csv
#   inflating: activations/img7/c1/output.csv
#   inflating: activations/img7/s2/input.csv
#   inflating: activations/img7/s2/output.csv
#   inflating: activations/img7/c3/input.csv
#   inflating: activations/img7/c3/output.csv
#   inflating: activations/img7/s4/input.csv
#   inflating: activations/img7/s4/output.csv
#   inflating: activations/img7/c5/input.csv
#   inflating: activations/img7/c5/output.csv
#   inflating: activations/img7/f6/input.csv
#   inflating: activations/img7/f6/output.csv
#   inflating: activations/img7/output/input.csv
#   inflating: activations/img7/output/output.csv
#   inflating: activations/img8/input.csv
#   inflating: activations/img8/output.csv
#   inflating: activations/img8/c1/input.csv
#   inflating: activations/img8/c1/output.csv
#   inflating: activations/img8/s2/input.csv
#   inflating: activations/img8/s2/output.csv
#   inflating: activations/img8/c3/input.csv
#   inflating: activations/img8/c3/output.csv
#   inflating: activations/img8/s4/input.csv
#   inflating: activations/img8/s4/output.csv
#   inflating: activations/img8/c5/input.csv
#   inflating: activations/img8/c5/output.csv
#   inflating: activations/img8/f6/input.csv
#   inflating: activations/img8/f6/output.csv
#   inflating: activations/img8/output/input.csv
#   inflating: activations/img8/output/output.csv
#   inflating: activations/img9/input.csv
#   inflating: activations/img9/output.csv
#   inflating: activations/img9/c1/input.csv
#   inflating: activations/img9/c1/output.csv
#   inflating: activations/img9/s2/input.csv
#   inflating: activations/img9/s2/output.csv
#   inflating: activations/img9/c3/input.csv
#   inflating: activations/img9/c3/output.csv
#   inflating: activations/img9/s4/input.csv
#   inflating: activations/img9/s4/output.csv
#   inflating: activations/img9/c5/input.csv
#   inflating: activations/img9/c5/output.csv
#   inflating: activations/img9/f6/input.csv
#   inflating: activations/img9/f6/output.csv
#   inflating: activations/img9/output/input.csv
#   inflating: activations/img9/output/output.csv
#   inflating: activations/img10/input.csv
#   inflating: activations/img10/output.csv
#   inflating: activations/img10/c1/input.csv
#   inflating: activations/img10/c1/output.csv
#   inflating: activations/img10/s2/input.csv
#   inflating: activations/img10/s2/output.csv
#   inflating: activations/img10/c3/input.csv
#   inflating: activations/img10/c3/output.csv
#   inflating: activations/img10/s4/input.csv
#   inflating: activations/img10/s4/output.csv
#   inflating: activations/img10/c5/input.csv
#   inflating: activations/img10/c5/output.csv
#   inflating: activations/img10/f6/input.csv
#   inflating: activations/img10/f6/output.csv
#   inflating: activations/img10/output/input.csv
#   inflating: activations/img10/output/output.csv
#   inflating: activations/img11/input.csv
#   inflating: activations/img11/output.csv
#   inflating: activations/img11/c1/input.csv
#   inflating: activations/img11/c1/output.csv
#   inflating: activations/img11/s2/input.csv
#   inflating: activations/img11/s2/output.csv
#   inflating: activations/img11/c3/input.csv
#   inflating: activations/img11/c3/output.csv
#   inflating: activations/img11/s4/input.csv
#   inflating: activations/img11/s4/output.csv
#   inflating: activations/img11/c5/input.csv
#   inflating: activations/img11/c5/output.csv
#   inflating: activations/img11/f6/input.csv
#   inflating: activations/img11/f6/output.csv
#   inflating: activations/img11/output/input.csv
#   inflating: activations/img11/output/output.csv
#   inflating: activations/img12/input.csv
#   inflating: activations/img12/output.csv
#   inflating: activations/img12/c1/input.csv
#   inflating: activations/img12/c1/output.csv
#   inflating: activations/img12/s2/input.csv
#   inflating: activations/img12/s2/output.csv
#   inflating: activations/img12/c3/input.csv
#   inflating: activations/img12/c3/output.csv
#   inflating: activations/img12/s4/input.csv
#   inflating: activations/img12/s4/output.csv
#   inflating: activations/img12/c5/input.csv
#   inflating: activations/img12/c5/output.csv
#   inflating: activations/img12/f6/input.csv
#   inflating: activations/img12/f6/output.csv
#   inflating: activations/img12/output/input.csv
#   inflating: activations/img12/output/output.csv
#   inflating: activations/img13/input.csv
#   inflating: activations/img13/output.csv
#   inflating: activations/img13/c1/input.csv
#   inflating: activations/img13/c1/output.csv
#   inflating: activations/img13/s2/input.csv
#   inflating: activations/img13/s2/output.csv
#   inflating: activations/img13/c3/input.csv
#   inflating: activations/img13/c3/output.csv
#   inflating: activations/img13/s4/input.csv
#   inflating: activations/img13/s4/output.csv
#   inflating: activations/img13/c5/input.csv
#   inflating: activations/img13/c5/output.csv
#   inflating: activations/img13/f6/input.csv
#   inflating: activations/img13/f6/output.csv
#   inflating: activations/img13/output/input.csv
#   inflating: activations/img13/output/output.csv
#   inflating: activations/img14/input.csv
#   inflating: activations/img14/output.csv
#   inflating: activations/img14/c1/input.csv
#   inflating: activations/img14/c1/output.csv
#   inflating: activations/img14/s2/input.csv
#   inflating: activations/img14/s2/output.csv
#   inflating: activations/img14/c3/input.csv
#   inflating: activations/img14/c3/output.csv
#   inflating: activations/img14/s4/input.csv
#   inflating: activations/img14/s4/output.csv
#   inflating: activations/img14/c5/input.csv
#   inflating: activations/img14/c5/output.csv
#   inflating: activations/img14/f6/input.csv
#   inflating: activations/img14/f6/output.csv
#   inflating: activations/img14/output/input.csv
#   inflating: activations/img14/output/output.csv
#   inflating: activations/img15/input.csv
#   inflating: activations/img15/output.csv
#   inflating: activations/img15/c1/input.csv
#   inflating: activations/img15/c1/output.csv
#   inflating: activations/img15/s2/input.csv
#   inflating: activations/img15/s2/output.csv
#   inflating: activations/img15/c3/input.csv
#   inflating: activations/img15/c3/output.csv
#   inflating: activations/img15/s4/input.csv
#   inflating: activations/img15/s4/output.csv
#   inflating: activations/img15/c5/input.csv
#   inflating: activations/img15/c5/output.csv
#   inflating: activations/img15/f6/input.csv
#   inflating: activations/img15/f6/output.csv
#   inflating: activations/img15/output/input.csv
#   inflating: activations/img15/output/output.csv
#   inflating: activations/img16/input.csv
#   inflating: activations/img16/output.csv
#   inflating: activations/img16/c1/input.csv
#   inflating: activations/img16/c1/output.csv
#   inflating: activations/img16/s2/input.csv
#   inflating: activations/img16/s2/output.csv
#   inflating: activations/img16/c3/input.csv
#   inflating: activations/img16/c3/output.csv
#   inflating: activations/img16/s4/input.csv
#   inflating: activations/img16/s4/output.csv
#   inflating: activations/img16/c5/input.csv
#   inflating: activations/img16/c5/output.csv
#   inflating: activations/img16/f6/input.csv
#   inflating: activations/img16/f6/output.csv
#   inflating: activations/img16/output/input.csv
#   inflating: activations/img16/output/output.csv
#   inflating: activations/img17/input.csv
#   inflating: activations/img17/output.csv
#   inflating: activations/img17/c1/input.csv
#   inflating: activations/img17/c1/output.csv
#   inflating: activations/img17/s2/input.csv
#   inflating: activations/img17/s2/output.csv
#   inflating: activations/img17/c3/input.csv
#   inflating: activations/img17/c3/output.csv
#   inflating: activations/img17/s4/input.csv
#   inflating: activations/img17/s4/output.csv
#   inflating: activations/img17/c5/input.csv
#   inflating: activations/img17/c5/output.csv
#   inflating: activations/img17/f6/input.csv
#   inflating: activations/img17/f6/output.csv
#   inflating: activations/img17/output/input.csv
#   inflating: activations/img17/output/output.csv
#   inflating: activations/img18/input.csv
#   inflating: activations/img18/output.csv
#   inflating: activations/img18/c1/input.csv
#   inflating: activations/img18/c1/output.csv
#   inflating: activations/img18/s2/input.csv
#   inflating: activations/img18/s2/output.csv
#   inflating: activations/img18/c3/input.csv
#   inflating: activations/img18/c3/output.csv
#   inflating: activations/img18/s4/input.csv
#   inflating: activations/img18/s4/output.csv
#   inflating: activations/img18/c5/input.csv
#   inflating: activations/img18/c5/output.csv
#   inflating: activations/img18/f6/input.csv
#   inflating: activations/img18/f6/output.csv
#   inflating: activations/img18/output/input.csv
#   inflating: activations/img18/output/output.csv
#   inflating: activations/img19/input.csv
#   inflating: activations/img19/output.csv
#   inflating: activations/img19/c1/input.csv
#   inflating: activations/img19/c1/output.csv
#   inflating: activations/img19/s2/input.csv
#   inflating: activations/img19/s2/output.csv
#   inflating: activations/img19/c3/input.csv
#   inflating: activations/img19/c3/output.csv
#   inflating: activations/img19/s4/input.csv
#   inflating: activations/img19/s4/output.csv
#   inflating: activations/img19/c5/input.csv
#   inflating: activations/img19/c5/output.csv
#   inflating: activations/img19/f6/input.csv
#   inflating: activations/img19/f6/output.csv
#   inflating: activations/img19/output/input.csv
#   inflating: activations/img19/output/output.csv
#   inflating: activations/img20/input.csv
#   inflating: activations/img20/output.csv
#   inflating: activations/img20/c1/input.csv
#   inflating: activations/img20/c1/output.csv
#   inflating: activations/img20/s2/input.csv
#   inflating: activations/img20/s2/output.csv
#   inflating: activations/img20/c3/input.csv
#   inflating: activations/img20/c3/output.csv
#   inflating: activations/img20/s4/input.csv
#   inflating: activations/img20/s4/output.csv
#   inflating: activations/img20/c5/input.csv
#   inflating: activations/img20/c5/output.csv
#   inflating: activations/img20/f6/input.csv
#   inflating: activations/img20/f6/output.csv
#   inflating: activations/img20/output/input.csv
#   inflating: activations/img20/output/output.csv
#   inflating: activations/img21/input.csv
#   inflating: activations/img21/output.csv
#   inflating: activations/img21/c1/input.csv
#   inflating: activations/img21/c1/output.csv
#   inflating: activations/img21/s2/input.csv
#   inflating: activations/img21/s2/output.csv
#   inflating: activations/img21/c3/input.csv
#   inflating: activations/img21/c3/output.csv
#   inflating: activations/img21/s4/input.csv
#   inflating: activations/img21/s4/output.csv
#   inflating: activations/img21/c5/input.csv
#   inflating: activations/img21/c5/output.csv
#   inflating: activations/img21/f6/input.csv
#   inflating: activations/img21/f6/output.csv
#   inflating: activations/img21/output/input.csv
#   inflating: activations/img21/output/output.csv
#   inflating: activations/img22/input.csv
#   inflating: activations/img22/output.csv
#   inflating: activations/img22/c1/input.csv
#   inflating: activations/img22/c1/output.csv
#   inflating: activations/img22/s2/input.csv
#   inflating: activations/img22/s2/output.csv
#   inflating: activations/img22/c3/input.csv
#   inflating: activations/img22/c3/output.csv
#   inflating: activations/img22/s4/input.csv
#   inflating: activations/img22/s4/output.csv
#   inflating: activations/img22/c5/input.csv
#   inflating: activations/img22/c5/output.csv
#   inflating: activations/img22/f6/input.csv
#   inflating: activations/img22/f6/output.csv
#   inflating: activations/img22/output/input.csv
#   inflating: activations/img22/output/output.csv
#   inflating: activations/img23/input.csv
#   inflating: activations/img23/output.csv
#   inflating: activations/img23/c1/input.csv
#   inflating: activations/img23/c1/output.csv
#   inflating: activations/img23/s2/input.csv
#   inflating: activations/img23/s2/output.csv
#   inflating: activations/img23/c3/input.csv
#   inflating: activations/img23/c3/output.csv
#   inflating: activations/img23/s4/input.csv
#   inflating: activations/img23/s4/output.csv
#   inflating: activations/img23/c5/input.csv
#   inflating: activations/img23/c5/output.csv
#   inflating: activations/img23/f6/input.csv
#   inflating: activations/img23/f6/output.csv
#   inflating: activations/img23/output/input.csv
#   inflating: activations/img23/output/output.csv
#   inflating: activations/img24/input.csv
#   inflating: activations/img24/output.csv
#   inflating: activations/img24/c1/input.csv
#   inflating: activations/img24/c1/output.csv
#   inflating: activations/img24/s2/input.csv
#   inflating: activations/img24/s2/output.csv
#   inflating: activations/img24/c3/input.csv
#   inflating: activations/img24/c3/output.csv
#   inflating: activations/img24/s4/input.csv
#   inflating: activations/img24/s4/output.csv
#   inflating: activations/img24/c5/input.csv
#   inflating: activations/img24/c5/output.csv
#   inflating: activations/img24/f6/input.csv
#   inflating: activations/img24/f6/output.csv
#   inflating: activations/img24/output/input.csv
#   inflating: activations/img24/output/output.csv
#   inflating: activations/img25/input.csv
#   inflating: activations/img25/output.csv
#   inflating: activations/img25/c1/input.csv
#   inflating: activations/img25/c1/output.csv
#   inflating: activations/img25/s2/input.csv
#   inflating: activations/img25/s2/output.csv
#   inflating: activations/img25/c3/input.csv
#   inflating: activations/img25/c3/output.csv
#   inflating: activations/img25/s4/input.csv
#   inflating: activations/img25/s4/output.csv
#   inflating: activations/img25/c5/input.csv
#   inflating: activations/img25/c5/output.csv
#   inflating: activations/img25/f6/input.csv
#   inflating: activations/img25/f6/output.csv
#   inflating: activations/img25/output/input.csv
#   inflating: activations/img25/output/output.csv
#   inflating: activations/img26/input.csv
#   inflating: activations/img26/output.csv
#   inflating: activations/img26/c1/input.csv
#   inflating: activations/img26/c1/output.csv
#   inflating: activations/img26/s2/input.csv
#   inflating: activations/img26/s2/output.csv
#   inflating: activations/img26/c3/input.csv
#   inflating: activations/img26/c3/output.csv
#   inflating: activations/img26/s4/input.csv
#   inflating: activations/img26/s4/output.csv
#   inflating: activations/img26/c5/input.csv
#   inflating: activations/img26/c5/output.csv
#   inflating: activations/img26/f6/input.csv
#   inflating: activations/img26/f6/output.csv
#   inflating: activations/img26/output/input.csv
#   inflating: activations/img26/output/output.csv
#   inflating: activations/img27/input.csv
#   inflating: activations/img27/output.csv
#   inflating: activations/img27/c1/input.csv
#   inflating: activations/img27/c1/output.csv
#   inflating: activations/img27/s2/input.csv
#   inflating: activations/img27/s2/output.csv
#   inflating: activations/img27/c3/input.csv
#   inflating: activations/img27/c3/output.csv
#   inflating: activations/img27/s4/input.csv
#   inflating: activations/img27/s4/output.csv
#   inflating: activations/img27/c5/input.csv
#   inflating: activations/img27/c5/output.csv
#   inflating: activations/img27/f6/input.csv
#   inflating: activations/img27/f6/output.csv
#   inflating: activations/img27/output/input.csv
#   inflating: activations/img27/output/output.csv
#   inflating: activations/img28/input.csv
#   inflating: activations/img28/output.csv
#   inflating: activations/img28/c1/input.csv
#   inflating: activations/img28/c1/output.csv
#   inflating: activations/img28/s2/input.csv
#   inflating: activations/img28/s2/output.csv
#   inflating: activations/img28/c3/input.csv
#   inflating: activations/img28/c3/output.csv
#   inflating: activations/img28/s4/input.csv
#   inflating: activations/img28/s4/output.csv
#   inflating: activations/img28/c5/input.csv
#   inflating: activations/img28/c5/output.csv
#   inflating: activations/img28/f6/input.csv
#   inflating: activations/img28/f6/output.csv
#   inflating: activations/img28/output/input.csv
#   inflating: activations/img28/output/output.csv
#   inflating: activations/img29/input.csv
#   inflating: activations/img29/output.csv
#   inflating: activations/img29/c1/input.csv
#   inflating: activations/img29/c1/output.csv
#   inflating: activations/img29/s2/input.csv
#   inflating: activations/img29/s2/output.csv
#   inflating: activations/img29/c3/input.csv
#   inflating: activations/img29/c3/output.csv
#   inflating: activations/img29/s4/input.csv
#   inflating: activations/img29/s4/output.csv
#   inflating: activations/img29/c5/input.csv
#   inflating: activations/img29/c5/output.csv
#   inflating: activations/img29/f6/input.csv
#   inflating: activations/img29/f6/output.csv
#   inflating: activations/img29/output/input.csv
#   inflating: activations/img29/output/output.csv
#   inflating: activations/img30/input.csv
#   inflating: activations/img30/output.csv
#   inflating: activations/img30/c1/input.csv
#   inflating: activations/img30/c1/output.csv
#   inflating: activations/img30/s2/input.csv
#   inflating: activations/img30/s2/output.csv
#   inflating: activations/img30/c3/input.csv
#   inflating: activations/img30/c3/output.csv
#   inflating: activations/img30/s4/input.csv
#   inflating: activations/img30/s4/output.csv
#   inflating: activations/img30/c5/input.csv
#   inflating: activations/img30/c5/output.csv
#   inflating: activations/img30/f6/input.csv
#   inflating: activations/img30/f6/output.csv
#   inflating: activations/img30/output/input.csv
#   inflating: activations/img30/output/output.csv
#   inflating: activations/img31/input.csv
#   inflating: activations/img31/output.csv
#   inflating: activations/img31/c1/input.csv
#   inflating: activations/img31/c1/output.csv
#   inflating: activations/img31/s2/input.csv
#   inflating: activations/img31/s2/output.csv
#   inflating: activations/img31/c3/input.csv
#   inflating: activations/img31/c3/output.csv
#   inflating: activations/img31/s4/input.csv
#   inflating: activations/img31/s4/output.csv
#   inflating: activations/img31/c5/input.csv
#   inflating: activations/img31/c5/output.csv
#   inflating: activations/img31/f6/input.csv
#   inflating: activations/img31/f6/output.csv
#   inflating: activations/img31/output/input.csv
#   inflating: activations/img31/output/output.csv
#   inflating: activations/img32/input.csv
#   inflating: activations/img32/output.csv
#   inflating: activations/img32/c1/input.csv
#   inflating: activations/img32/c1/output.csv
#   inflating: activations/img32/s2/input.csv
#   inflating: activations/img32/s2/output.csv
#   inflating: activations/img32/c3/input.csv
#   inflating: activations/img32/c3/output.csv
#   inflating: activations/img32/s4/input.csv
#   inflating: activations/img32/s4/output.csv
#   inflating: activations/img32/c5/input.csv
#   inflating: activations/img32/c5/output.csv
#   inflating: activations/img32/f6/input.csv
#   inflating: activations/img32/f6/output.csv
#   inflating: activations/img32/output/input.csv
#   inflating: activations/img32/output/output.csv
#   inflating: activations/img33/input.csv
#   inflating: activations/img33/output.csv
#   inflating: activations/img33/c1/input.csv
#   inflating: activations/img33/c1/output.csv
#   inflating: activations/img33/s2/input.csv
#   inflating: activations/img33/s2/output.csv
#   inflating: activations/img33/c3/input.csv
#   inflating: activations/img33/c3/output.csv
#   inflating: activations/img33/s4/input.csv
#   inflating: activations/img33/s4/output.csv
#   inflating: activations/img33/c5/input.csv
#   inflating: activations/img33/c5/output.csv
#   inflating: activations/img33/f6/input.csv
#   inflating: activations/img33/f6/output.csv
#   inflating: activations/img33/output/input.csv
#   inflating: activations/img33/output/output.csv
#   inflating: activations/img34/input.csv
#   inflating: activations/img34/output.csv
#   inflating: activations/img34/c1/input.csv
#   inflating: activations/img34/c1/output.csv
#   inflating: activations/img34/s2/input.csv
#   inflating: activations/img34/s2/output.csv
#   inflating: activations/img34/c3/input.csv
#   inflating: activations/img34/c3/output.csv
#   inflating: activations/img34/s4/input.csv
#   inflating: activations/img34/s4/output.csv
#   inflating: activations/img34/c5/input.csv
#   inflating: activations/img34/c5/output.csv
#   inflating: activations/img34/f6/input.csv
#   inflating: activations/img34/f6/output.csv
#   inflating: activations/img34/output/input.csv
#   inflating: activations/img34/output/output.csv
#   inflating: activations/img35/input.csv
#   inflating: activations/img35/output.csv
#   inflating: activations/img35/c1/input.csv
#   inflating: activations/img35/c1/output.csv
#   inflating: activations/img35/s2/input.csv
#   inflating: activations/img35/s2/output.csv
#   inflating: activations/img35/c3/input.csv
#   inflating: activations/img35/c3/output.csv
#   inflating: activations/img35/s4/input.csv
#   inflating: activations/img35/s4/output.csv
#   inflating: activations/img35/c5/input.csv
#   inflating: activations/img35/c5/output.csv
#   inflating: activations/img35/f6/input.csv
#   inflating: activations/img35/f6/output.csv
#   inflating: activations/img35/output/input.csv
#   inflating: activations/img35/output/output.csv
#   inflating: activations/img36/input.csv
#   inflating: activations/img36/output.csv
#   inflating: activations/img36/c1/input.csv
#   inflating: activations/img36/c1/output.csv
#   inflating: activations/img36/s2/input.csv
#   inflating: activations/img36/s2/output.csv
#   inflating: activations/img36/c3/input.csv
#   inflating: activations/img36/c3/output.csv
#   inflating: activations/img36/s4/input.csv
#   inflating: activations/img36/s4/output.csv
#   inflating: activations/img36/c5/input.csv
#   inflating: activations/img36/c5/output.csv
#   inflating: activations/img36/f6/input.csv
#   inflating: activations/img36/f6/output.csv
#   inflating: activations/img36/output/input.csv
#   inflating: activations/img36/output/output.csv
#   inflating: activations/img37/input.csv
#   inflating: activations/img37/output.csv
#   inflating: activations/img37/c1/input.csv
#   inflating: activations/img37/c1/output.csv
#   inflating: activations/img37/s2/input.csv
#   inflating: activations/img37/s2/output.csv
#   inflating: activations/img37/c3/input.csv
#   inflating: activations/img37/c3/output.csv
#   inflating: activations/img37/s4/input.csv
#   inflating: activations/img37/s4/output.csv
#   inflating: activations/img37/c5/input.csv
#   inflating: activations/img37/c5/output.csv
#   inflating: activations/img37/f6/input.csv
#   inflating: activations/img37/f6/output.csv
#   inflating: activations/img37/output/input.csv
#   inflating: activations/img37/output/output.csv
#   inflating: activations/img38/input.csv
#   inflating: activations/img38/output.csv
#   inflating: activations/img38/c1/input.csv
#   inflating: activations/img38/c1/output.csv
#   inflating: activations/img38/s2/input.csv
#   inflating: activations/img38/s2/output.csv
#   inflating: activations/img38/c3/input.csv
#   inflating: activations/img38/c3/output.csv
#   inflating: activations/img38/s4/input.csv
#   inflating: activations/img38/s4/output.csv
#   inflating: activations/img38/c5/input.csv
#   inflating: activations/img38/c5/output.csv
#   inflating: activations/img38/f6/input.csv
#   inflating: activations/img38/f6/output.csv
#   inflating: activations/img38/output/input.csv
#   inflating: activations/img38/output/output.csv
#   inflating: activations/img39/input.csv
#   inflating: activations/img39/output.csv
#   inflating: activations/img39/c1/input.csv
#   inflating: activations/img39/c1/output.csv
#   inflating: activations/img39/s2/input.csv
#   inflating: activations/img39/s2/output.csv
#   inflating: activations/img39/c3/input.csv
#   inflating: activations/img39/c3/output.csv
#   inflating: activations/img39/s4/input.csv
#   inflating: activations/img39/s4/output.csv
#   inflating: activations/img39/c5/input.csv
#   inflating: activations/img39/c5/output.csv
#   inflating: activations/img39/f6/input.csv
#   inflating: activations/img39/f6/output.csv
#   inflating: activations/img39/output/input.csv
#   inflating: activations/img39/output/output.csv
#   inflating: activations/img40/input.csv
#   inflating: activations/img40/output.csv
#   inflating: activations/img40/c1/input.csv
#   inflating: activations/img40/c1/output.csv
#   inflating: activations/img40/s2/input.csv
#   inflating: activations/img40/s2/output.csv
#   inflating: activations/img40/c3/input.csv
#   inflating: activations/img40/c3/output.csv
#   inflating: activations/img40/s4/input.csv
#   inflating: activations/img40/s4/output.csv
#   inflating: activations/img40/c5/input.csv
#   inflating: activations/img40/c5/output.csv
#   inflating: activations/img40/f6/input.csv
#   inflating: activations/img40/f6/output.csv
#   inflating: activations/img40/output/input.csv
#   inflating: activations/img40/output/output.csv
#   inflating: activations/img41/input.csv
#   inflating: activations/img41/output.csv
#   inflating: activations/img41/c1/input.csv
#   inflating: activations/img41/c1/output.csv
#   inflating: activations/img41/s2/input.csv
#   inflating: activations/img41/s2/output.csv
#   inflating: activations/img41/c3/input.csv
#   inflating: activations/img41/c3/output.csv
#   inflating: activations/img41/s4/input.csv
#   inflating: activations/img41/s4/output.csv
#   inflating: activations/img41/c5/input.csv
#   inflating: activations/img41/c5/output.csv
#   inflating: activations/img41/f6/input.csv
#   inflating: activations/img41/f6/output.csv
#   inflating: activations/img41/output/input.csv
#   inflating: activations/img41/output/output.csv
#   inflating: activations/img42/input.csv
#   inflating: activations/img42/output.csv
#   inflating: activations/img42/c1/input.csv
#   inflating: activations/img42/c1/output.csv
#   inflating: activations/img42/s2/input.csv
#   inflating: activations/img42/s2/output.csv
#   inflating: activations/img42/c3/input.csv
#   inflating: activations/img42/c3/output.csv
#   inflating: activations/img42/s4/input.csv
#   inflating: activations/img42/s4/output.csv
#   inflating: activations/img42/c5/input.csv
#   inflating: activations/img42/c5/output.csv
#   inflating: activations/img42/f6/input.csv
#   inflating: activations/img42/f6/output.csv
#   inflating: activations/img42/output/input.csv
#   inflating: activations/img42/output/output.csv
#   inflating: activations/img43/input.csv
#   inflating: activations/img43/output.csv
#   inflating: activations/img43/c1/input.csv
#   inflating: activations/img43/c1/output.csv
#   inflating: activations/img43/s2/input.csv
#   inflating: activations/img43/s2/output.csv
#   inflating: activations/img43/c3/input.csv
#   inflating: activations/img43/c3/output.csv
#   inflating: activations/img43/s4/input.csv
#   inflating: activations/img43/s4/output.csv
#   inflating: activations/img43/c5/input.csv
#   inflating: activations/img43/c5/output.csv
#   inflating: activations/img43/f6/input.csv
#   inflating: activations/img43/f6/output.csv
#   inflating: activations/img43/output/input.csv
#   inflating: activations/img43/output/output.csv
#   inflating: activations/img44/input.csv
#   inflating: activations/img44/output.csv
#   inflating: activations/img44/c1/input.csv
#   inflating: activations/img44/c1/output.csv
#   inflating: activations/img44/s2/input.csv
#   inflating: activations/img44/s2/output.csv
#   inflating: activations/img44/c3/input.csv
#   inflating: activations/img44/c3/output.csv
#   inflating: activations/img44/s4/input.csv
#   inflating: activations/img44/s4/output.csv
#   inflating: activations/img44/c5/input.csv
#   inflating: activations/img44/c5/output.csv
#   inflating: activations/img44/f6/input.csv
#   inflating: activations/img44/f6/output.csv
#   inflating: activations/img44/output/input.csv
#   inflating: activations/img44/output/output.csv
#   inflating: activations/img45/input.csv
#   inflating: activations/img45/output.csv
#   inflating: activations/img45/c1/input.csv
#   inflating: activations/img45/c1/output.csv
#   inflating: activations/img45/s2/input.csv
#   inflating: activations/img45/s2/output.csv
#   inflating: activations/img45/c3/input.csv
#   inflating: activations/img45/c3/output.csv
#   inflating: activations/img45/s4/input.csv
#   inflating: activations/img45/s4/output.csv
#   inflating: activations/img45/c5/input.csv
#   inflating: activations/img45/c5/output.csv
#   inflating: activations/img45/f6/input.csv
#   inflating: activations/img45/f6/output.csv
#   inflating: activations/img45/output/input.csv
#   inflating: activations/img45/output/output.csv
#   inflating: activations/img46/input.csv
#   inflating: activations/img46/output.csv
#   inflating: activations/img46/c1/input.csv
#   inflating: activations/img46/c1/output.csv
#   inflating: activations/img46/s2/input.csv
#   inflating: activations/img46/s2/output.csv
#   inflating: activations/img46/c3/input.csv
#   inflating: activations/img46/c3/output.csv
#   inflating: activations/img46/s4/input.csv
#   inflating: activations/img46/s4/output.csv
#   inflating: activations/img46/c5/input.csv
#   inflating: activations/img46/c5/output.csv
#   inflating: activations/img46/f6/input.csv
#   inflating: activations/img46/f6/output.csv
#   inflating: activations/img46/output/input.csv
#   inflating: activations/img46/output/output.csv
#   inflating: activations/img47/input.csv
#   inflating: activations/img47/output.csv
#   inflating: activations/img47/c1/input.csv
#   inflating: activations/img47/c1/output.csv
#   inflating: activations/img47/s2/input.csv
#   inflating: activations/img47/s2/output.csv
#   inflating: activations/img47/c3/input.csv
#   inflating: activations/img47/c3/output.csv
#   inflating: activations/img47/s4/input.csv
#   inflating: activations/img47/s4/output.csv
#   inflating: activations/img47/c5/input.csv
#   inflating: activations/img47/c5/output.csv
#   inflating: activations/img47/f6/input.csv
#   inflating: activations/img47/f6/output.csv
#   inflating: activations/img47/output/input.csv
#   inflating: activations/img47/output/output.csv
#   inflating: activations/img48/input.csv
#   inflating: activations/img48/output.csv
#   inflating: activations/img48/c1/input.csv
#   inflating: activations/img48/c1/output.csv
#   inflating: activations/img48/s2/input.csv
#   inflating: activations/img48/s2/output.csv
#   inflating: activations/img48/c3/input.csv
#   inflating: activations/img48/c3/output.csv
#   inflating: activations/img48/s4/input.csv
#   inflating: activations/img48/s4/output.csv
#   inflating: activations/img48/c5/input.csv
#   inflating: activations/img48/c5/output.csv
#   inflating: activations/img48/f6/input.csv
#   inflating: activations/img48/f6/output.csv
#   inflating: activations/img48/output/input.csv
#   inflating: activations/img48/output/output.csv
#   inflating: activations/img49/input.csv
#   inflating: activations/img49/output.csv
#   inflating: activations/img49/c1/input.csv
#   inflating: activations/img49/c1/output.csv
#   inflating: activations/img49/s2/input.csv
#   inflating: activations/img49/s2/output.csv
#   inflating: activations/img49/c3/input.csv
#   inflating: activations/img49/c3/output.csv
#   inflating: activations/img49/s4/input.csv
#   inflating: activations/img49/s4/output.csv
#   inflating: activations/img49/c5/input.csv
#   inflating: activations/img49/c5/output.csv
#   inflating: activations/img49/f6/input.csv
#   inflating: activations/img49/f6/output.csv
#   inflating: activations/img49/output/input.csv
#   inflating: activations/img49/output/output.csv
#   inflating: activations/img50/input.csv
#   inflating: activations/img50/output.csv
#   inflating: activations/img50/c1/input.csv
#   inflating: activations/img50/c1/output.csv
#   inflating: activations/img50/s2/input.csv
#   inflating: activations/img50/s2/output.csv
#   inflating: activations/img50/c3/input.csv
#   inflating: activations/img50/c3/output.csv
#   inflating: activations/img50/s4/input.csv
#   inflating: activations/img50/s4/output.csv
#   inflating: activations/img50/c5/input.csv
#   inflating: activations/img50/c5/output.csv
#   inflating: activations/img50/f6/input.csv
#   inflating: activations/img50/f6/output.csv
#   inflating: activations/img50/output/input.csv
#   inflating: activations/img50/output/output.csv
#   inflating: activations/img51/input.csv
#   inflating: activations/img51/output.csv
#   inflating: activations/img51/c1/input.csv
#   inflating: activations/img51/c1/output.csv
#   inflating: activations/img51/s2/input.csv
#   inflating: activations/img51/s2/output.csv
#   inflating: activations/img51/c3/input.csv
#   inflating: activations/img51/c3/output.csv
#   inflating: activations/img51/s4/input.csv
#   inflating: activations/img51/s4/output.csv
#   inflating: activations/img51/c5/input.csv
#   inflating: activations/img51/c5/output.csv
#   inflating: activations/img51/f6/input.csv
#   inflating: activations/img51/f6/output.csv
#   inflating: activations/img51/output/input.csv
#   inflating: activations/img51/output/output.csv
#   inflating: activations/img52/input.csv
#   inflating: activations/img52/output.csv
#   inflating: activations/img52/c1/input.csv
#   inflating: activations/img52/c1/output.csv
#   inflating: activations/img52/s2/input.csv
#   inflating: activations/img52/s2/output.csv
#   inflating: activations/img52/c3/input.csv
#   inflating: activations/img52/c3/output.csv
#   inflating: activations/img52/s4/input.csv
#   inflating: activations/img52/s4/output.csv
#   inflating: activations/img52/c5/input.csv
#   inflating: activations/img52/c5/output.csv
#   inflating: activations/img52/f6/input.csv
#   inflating: activations/img52/f6/output.csv
#   inflating: activations/img52/output/input.csv
#   inflating: activations/img52/output/output.csv
#   inflating: activations/img53/input.csv
#   inflating: activations/img53/output.csv
#   inflating: activations/img53/c1/input.csv
#   inflating: activations/img53/c1/output.csv
#   inflating: activations/img53/s2/input.csv
#   inflating: activations/img53/s2/output.csv
#   inflating: activations/img53/c3/input.csv
#   inflating: activations/img53/c3/output.csv
#   inflating: activations/img53/s4/input.csv
#   inflating: activations/img53/s4/output.csv
#   inflating: activations/img53/c5/input.csv
#   inflating: activations/img53/c5/output.csv
#   inflating: activations/img53/f6/input.csv
#   inflating: activations/img53/f6/output.csv
#   inflating: activations/img53/output/input.csv
#   inflating: activations/img53/output/output.csv
#   inflating: activations/img54/input.csv
#   inflating: activations/img54/output.csv
#   inflating: activations/img54/c1/input.csv
#   inflating: activations/img54/c1/output.csv
#   inflating: activations/img54/s2/input.csv
#   inflating: activations/img54/s2/output.csv
#   inflating: activations/img54/c3/input.csv
#   inflating: activations/img54/c3/output.csv
#   inflating: activations/img54/s4/input.csv
#   inflating: activations/img54/s4/output.csv
#   inflating: activations/img54/c5/input.csv
#   inflating: activations/img54/c5/output.csv
#   inflating: activations/img54/f6/input.csv
#   inflating: activations/img54/f6/output.csv
#   inflating: activations/img54/output/input.csv
#   inflating: activations/img54/output/output.csv
#   inflating: activations/img55/input.csv
#   inflating: activations/img55/output.csv
#   inflating: activations/img55/c1/input.csv
#   inflating: activations/img55/c1/output.csv
#   inflating: activations/img55/s2/input.csv
#   inflating: activations/img55/s2/output.csv
#   inflating: activations/img55/c3/input.csv
#   inflating: activations/img55/c3/output.csv
#   inflating: activations/img55/s4/input.csv
#   inflating: activations/img55/s4/output.csv
#   inflating: activations/img55/c5/input.csv
#   inflating: activations/img55/c5/output.csv
#   inflating: activations/img55/f6/input.csv
#   inflating: activations/img55/f6/output.csv
#   inflating: activations/img55/output/input.csv
#   inflating: activations/img55/output/output.csv
#   inflating: activations/img56/input.csv
#   inflating: activations/img56/output.csv
#   inflating: activations/img56/c1/input.csv
#   inflating: activations/img56/c1/output.csv
#   inflating: activations/img56/s2/input.csv
#   inflating: activations/img56/s2/output.csv
#   inflating: activations/img56/c3/input.csv
#   inflating: activations/img56/c3/output.csv
#   inflating: activations/img56/s4/input.csv
#   inflating: activations/img56/s4/output.csv
#   inflating: activations/img56/c5/input.csv
#   inflating: activations/img56/c5/output.csv
#   inflating: activations/img56/f6/input.csv
#   inflating: activations/img56/f6/output.csv
#   inflating: activations/img56/output/input.csv
#   inflating: activations/img56/output/output.csv
#   inflating: activations/img57/input.csv
#   inflating: activations/img57/output.csv
#   inflating: activations/img57/c1/input.csv
#   inflating: activations/img57/c1/output.csv
#   inflating: activations/img57/s2/input.csv
#   inflating: activations/img57/s2/output.csv
#   inflating: activations/img57/c3/input.csv
#   inflating: activations/img57/c3/output.csv
#   inflating: activations/img57/s4/input.csv
#   inflating: activations/img57/s4/output.csv
#   inflating: activations/img57/c5/input.csv
#   inflating: activations/img57/c5/output.csv
#   inflating: activations/img57/f6/input.csv
#   inflating: activations/img57/f6/output.csv
#   inflating: activations/img57/output/input.csv
#   inflating: activations/img57/output/output.csv
#   inflating: activations/img58/input.csv
#   inflating: activations/img58/output.csv
#   inflating: activations/img58/c1/input.csv
#   inflating: activations/img58/c1/output.csv
#   inflating: activations/img58/s2/input.csv
#   inflating: activations/img58/s2/output.csv
#   inflating: activations/img58/c3/input.csv
#   inflating: activations/img58/c3/output.csv
#   inflating: activations/img58/s4/input.csv
#   inflating: activations/img58/s4/output.csv
#   inflating: activations/img58/c5/input.csv
#   inflating: activations/img58/c5/output.csv
#   inflating: activations/img58/f6/input.csv
#   inflating: activations/img58/f6/output.csv
#   inflating: activations/img58/output/input.csv
#   inflating: activations/img58/output/output.csv
#   inflating: activations/img59/input.csv
#   inflating: activations/img59/output.csv
#   inflating: activations/img59/c1/input.csv
#   inflating: activations/img59/c1/output.csv
#   inflating: activations/img59/s2/input.csv
#   inflating: activations/img59/s2/output.csv
#   inflating: activations/img59/c3/input.csv
#   inflating: activations/img59/c3/output.csv
#   inflating: activations/img59/s4/input.csv
#   inflating: activations/img59/s4/output.csv
#   inflating: activations/img59/c5/input.csv
#   inflating: activations/img59/c5/output.csv
#   inflating: activations/img59/f6/input.csv
#   inflating: activations/img59/f6/output.csv
#   inflating: activations/img59/output/input.csv
#   inflating: activations/img59/output/output.csv
#   inflating: activations/img60/input.csv
#   inflating: activations/img60/output.csv
#   inflating: activations/img60/c1/input.csv
#   inflating: activations/img60/c1/output.csv
#   inflating: activations/img60/s2/input.csv
#   inflating: activations/img60/s2/output.csv
#   inflating: activations/img60/c3/input.csv
#   inflating: activations/img60/c3/output.csv
#   inflating: activations/img60/s4/input.csv
#   inflating: activations/img60/s4/output.csv
#   inflating: activations/img60/c5/input.csv
#   inflating: activations/img60/c5/output.csv
#   inflating: activations/img60/f6/input.csv
#   inflating: activations/img60/f6/output.csv
#   inflating: activations/img60/output/input.csv
#   inflating: activations/img60/output/output.csv
#   inflating: activations/img61/input.csv
#   inflating: activations/img61/output.csv
#   inflating: activations/img61/c1/input.csv
#   inflating: activations/img61/c1/output.csv
#   inflating: activations/img61/s2/input.csv
#   inflating: activations/img61/s2/output.csv
#   inflating: activations/img61/c3/input.csv
#   inflating: activations/img61/c3/output.csv
#   inflating: activations/img61/s4/input.csv
#   inflating: activations/img61/s4/output.csv
#   inflating: activations/img61/c5/input.csv
#   inflating: activations/img61/c5/output.csv
#   inflating: activations/img61/f6/input.csv
#   inflating: activations/img61/f6/output.csv
#   inflating: activations/img61/output/input.csv
#   inflating: activations/img61/output/output.csv
#   inflating: activations/img62/input.csv
#   inflating: activations/img62/output.csv
#   inflating: activations/img62/c1/input.csv
#   inflating: activations/img62/c1/output.csv
#   inflating: activations/img62/s2/input.csv
#   inflating: activations/img62/s2/output.csv
#   inflating: activations/img62/c3/input.csv
#   inflating: activations/img62/c3/output.csv
#   inflating: activations/img62/s4/input.csv
#   inflating: activations/img62/s4/output.csv
#   inflating: activations/img62/c5/input.csv
#   inflating: activations/img62/c5/output.csv
#   inflating: activations/img62/f6/input.csv
#   inflating: activations/img62/f6/output.csv
#   inflating: activations/img62/output/input.csv
#   inflating: activations/img62/output/output.csv
#   inflating: activations/img63/input.csv
#   inflating: activations/img63/output.csv
#   inflating: activations/img63/c1/input.csv
#   inflating: activations/img63/c1/output.csv
#   inflating: activations/img63/s2/input.csv
#   inflating: activations/img63/s2/output.csv
#   inflating: activations/img63/c3/input.csv
#   inflating: activations/img63/c3/output.csv
#   inflating: activations/img63/s4/input.csv
#   inflating: activations/img63/s4/output.csv
#   inflating: activations/img63/c5/input.csv
#   inflating: activations/img63/c5/output.csv
#   inflating: activations/img63/f6/input.csv
#   inflating: activations/img63/f6/output.csv
#   inflating: activations/img63/output/input.csv
#   inflating: activations/img63/output/output.csv
#   inflating: activations/img64/input.csv
#   inflating: activations/img64/output.csv
#   inflating: activations/img64/c1/input.csv
#   inflating: activations/img64/c1/output.csv
#   inflating: activations/img64/s2/input.csv
#   inflating: activations/img64/s2/output.csv
#   inflating: activations/img64/c3/input.csv
#   inflating: activations/img64/c3/output.csv
# ...
#   inflating: activations/img79/input.csv
#   inflating: activations/img79/output.csv
#   inflating: activations/img79/c1/input.csv
#   inflating: activations/img79/c1/output.csv
#   inflating: activations/img79/s2/input.csv
#   inflating: activations/img79/s2/output.csv
#   inflating: activations/img79/c3/input.csv
#   inflating: activations/img79/c3/output.csv
#   inflating: activations/img79/s4/input.csv
#   inflating: activations/img79/s4/output.csv
#   inflating: activations/img79/c5/input.csv
#   inflating: activations/img79/c5/output.csv
#   inflating: activations/img79/f6/input.csv
#   inflating: activations/img79/f6/output.csv
#   inflating: activations/img79/output/input.csv
#   inflating: activations/img79/output/output.csv
#   inflating: activations/img80/input.csv
#   inflating: activations/img80/output.csv
#   inflating: activations/img80/c1/input.csv
#   inflating: activations/img80/c1/output.csv
#   inflating: activations/img80/s2/input.csv
#   inflating: activations/img80/s2/output.csv
#   inflating: activations/img80/c3/input.csv
#   inflating: activations/img80/c3/output.csv
#   inflating: activations/img80/s4/input.csv
#   inflating: activations/img80/s4/output.csv
#   inflating: activations/img80/c5/input.csv
#   inflating: activations/img80/c5/output.csv
#   inflating: activations/img80/f6/input.csv
#   inflating: activations/img80/f6/output.csv
#   inflating: activations/img80/output/input.csv
#   inflating: activations/img80/output/output.csv
#   inflating: activations/img81/input.csv
#   inflating: activations/img81/output.csv
#   inflating: activations/img81/c1/input.csv
#   inflating: activations/img81/c1/output.csv
#   inflating: activations/img81/s2/input.csv
#   inflating: activations/img81/s2/output.csv
#   inflating: activations/img81/c3/input.csv
#   inflating: activations/img81/c3/output.csv
#   inflating: activations/img81/s4/input.csv
#   inflating: activations/img81/s4/output.csv
#   inflating: activations/img81/c5/input.csv
#   inflating: activations/img81/c5/output.csv
#   inflating: activations/img81/f6/input.csv
#   inflating: activations/img81/f6/output.csv
#   inflating: activations/img81/output/input.csv
#   inflating: activations/img81/output/output.csv
#   inflating: activations/img82/input.csv
#   inflating: activations/img82/output.csv
#   inflating: activations/img82/c1/input.csv
#   inflating: activations/img82/c1/output.csv
#   inflating: activations/img82/s2/input.csv
#   inflating: activations/img82/s2/output.csv
#   inflating: activations/img82/c3/input.csv
#   inflating: activations/img82/c3/output.csv
#   inflating: activations/img82/s4/input.csv
#   inflating: activations/img82/s4/output.csv
#   inflating: activations/img82/c5/input.csv
#   inflating: activations/img82/c5/output.csv
#   inflating: activations/img82/f6/input.csv
#   inflating: activations/img82/f6/output.csv
#   inflating: activations/img82/output/input.csv
#   inflating: activations/img82/output/output.csv
#   inflating: activations/img83/input.csv
#   inflating: activations/img83/output.csv
#   inflating: activations/img83/c1/input.csv
#   inflating: activations/img83/c1/output.csv
#   inflating: activations/img83/s2/input.csv
#   inflating: activations/img83/s2/output.csv
#   inflating: activations/img83/c3/input.csv
#   inflating: activations/img83/c3/output.csv
#   inflating: activations/img83/s4/input.csv
#   inflating: activations/img83/s4/output.csv
#   inflating: activations/img83/c5/input.csv
#   inflating: activations/img83/c5/output.csv
#   inflating: activations/img83/f6/input.csv
#   inflating: activations/img83/f6/output.csv
#   inflating: activations/img83/output/input.csv
#   inflating: activations/img83/output/output.csv
#   inflating: activations/img84/input.csv
#   inflating: activations/img84/output.csv
#   inflating: activations/img84/c1/input.csv
#   inflating: activations/img84/c1/output.csv
#   inflating: activations/img84/s2/input.csv
#   inflating: activations/img84/s2/output.csv
#   inflating: activations/img84/c3/input.csv
#   inflating: activations/img84/c3/output.csv
#   inflating: activations/img84/s4/input.csv
#   inflating: activations/img84/s4/output.csv
#   inflating: activations/img84/c5/input.csv
#   inflating: activations/img84/c5/output.csv
#   inflating: activations/img84/f6/input.csv
#   inflating: activations/img84/f6/output.csv
#   inflating: activations/img84/output/input.csv
#   inflating: activations/img84/output/output.csv
#   inflating: activations/img85/input.csv
#   inflating: activations/img85/output.csv
#   inflating: activations/img85/c1/input.csv
#   inflating: activations/img85/c1/output.csv
#   inflating: activations/img85/s2/input.csv
#   inflating: activations/img85/s2/output.csv
#   inflating: activations/img85/c3/input.csv
#   inflating: activations/img85/c3/output.csv
#   inflating: activations/img85/s4/input.csv
#   inflating: activations/img85/s4/output.csv
#   inflating: activations/img85/c5/input.csv
#   inflating: activations/img85/c5/output.csv
#   inflating: activations/img85/f6/input.csv
#   inflating: activations/img85/f6/output.csv
#   inflating: activations/img85/output/input.csv
#   inflating: activations/img85/output/output.csv
#   inflating: activations/img86/input.csv
#   inflating: activations/img86/output.csv
#   inflating: activations/img86/c1/input.csv
#   inflating: activations/img86/c1/output.csv
#   inflating: activations/img86/s2/input.csv
#   inflating: activations/img86/s2/output.csv
#   inflating: activations/img86/c3/input.csv
#   inflating: activations/img86/c3/output.csv
#   inflating: activations/img86/s4/input.csv
#   inflating: activations/img86/s4/output.csv
#   inflating: activations/img86/c5/input.csv
#   inflating: activations/img86/c5/output.csv
#   inflating: activations/img86/f6/input.csv
#   inflating: activations/img86/f6/output.csv
#   inflating: activations/img86/output/input.csv
#   inflating: activations/img86/output/output.csv
#   inflating: activations/img87/input.csv
#   inflating: activations/img87/output.csv
#   inflating: activations/img87/c1/input.csv
#   inflating: activations/img87/c1/output.csv
#   inflating: activations/img87/s2/input.csv
#   inflating: activations/img87/s2/output.csv
#   inflating: activations/img87/c3/input.csv
#   inflating: activations/img87/c3/output.csv
#   inflating: activations/img87/s4/input.csv
#   inflating: activations/img87/s4/output.csv
#   inflating: activations/img87/c5/input.csv
#   inflating: activations/img87/c5/output.csv
#   inflating: activations/img87/f6/input.csv
#   inflating: activations/img87/f6/output.csv
#   inflating: activations/img87/output/input.csv
#   inflating: activations/img87/output/output.csv
#   inflating: activations/img88/input.csv
#   inflating: activations/img88/output.csv
#   inflating: activations/img88/c1/input.csv
#   inflating: activations/img88/c1/output.csv
#   inflating: activations/img88/s2/input.csv
#   inflating: activations/img88/s2/output.csv
#   inflating: activations/img88/c3/input.csv
#   inflating: activations/img88/c3/output.csv
#   inflating: activations/img88/s4/input.csv
#   inflating: activations/img88/s4/output.csv
#   inflating: activations/img88/c5/input.csv
#   inflating: activations/img88/c5/output.csv
#   inflating: activations/img88/f6/input.csv
#   inflating: activations/img88/f6/output.csv
#   inflating: activations/img88/output/input.csv
#   inflating: activations/img88/output/output.csv
#   inflating: activations/img89/input.csv
#   inflating: activations/img89/output.csv
#   inflating: activations/img89/c1/input.csv
#   inflating: activations/img89/c1/output.csv
#   inflating: activations/img89/s2/input.csv
#   inflating: activations/img89/s2/output.csv
#   inflating: activations/img89/c3/input.csv
#   inflating: activations/img89/c3/output.csv
#   inflating: activations/img89/s4/input.csv
#   inflating: activations/img89/s4/output.csv
#   inflating: activations/img89/c5/input.csv
#   inflating: activations/img89/c5/output.csv
#   inflating: activations/img89/f6/input.csv
#   inflating: activations/img89/f6/output.csv
#   inflating: activations/img89/output/input.csv
#   inflating: activations/img89/output/output.csv
#   inflating: activations/img90/input.csv
#   inflating: activations/img90/output.csv
#   inflating: activations/img90/c1/input.csv
#   inflating: activations/img90/c1/output.csv
#   inflating: activations/img90/s2/input.csv
#   inflating: activations/img90/s2/output.csv
#   inflating: activations/img90/c3/input.csv
#   inflating: activations/img90/c3/output.csv
#   inflating: activations/img90/s4/input.csv
#   inflating: activations/img90/s4/output.csv
#   inflating: activations/img90/c5/input.csv
#   inflating: activations/img90/c5/output.csv
#   inflating: activations/img90/f6/input.csv
#   inflating: activations/img90/f6/output.csv
#   inflating: activations/img90/output/input.csv
#   inflating: activations/img90/output/output.csv
#   inflating: activations/img91/input.csv
#   inflating: activations/img91/output.csv
#   inflating: activations/img91/c1/input.csv
#   inflating: activations/img91/c1/output.csv
#   inflating: activations/img91/s2/input.csv
#   inflating: activations/img91/s2/output.csv
#   inflating: activations/img91/c3/input.csv
#   inflating: activations/img91/c3/output.csv
#   inflating: activations/img91/s4/input.csv
#   inflating: activations/img91/s4/output.csv
#   inflating: activations/img91/c5/input.csv
#   inflating: activations/img91/c5/output.csv
#   inflating: activations/img91/f6/input.csv
#   inflating: activations/img91/f6/output.csv
#   inflating: activations/img91/output/input.csv
#   inflating: activations/img91/output/output.csv
#   inflating: activations/img92/input.csv
#   inflating: activations/img92/output.csv
#   inflating: activations/img92/c1/input.csv
#   inflating: activations/img92/c1/output.csv
#   inflating: activations/img92/s2/input.csv
#   inflating: activations/img92/s2/output.csv
#   inflating: activations/img92/c3/input.csv
#   inflating: activations/img92/c3/output.csv
#   inflating: activations/img92/s4/input.csv
#   inflating: activations/img92/s4/output.csv
#   inflating: activations/img92/c5/input.csv
#   inflating: activations/img92/c5/output.csv
#   inflating: activations/img92/f6/input.csv
#   inflating: activations/img92/f6/output.csv
#   inflating: activations/img92/output/input.csv
#   inflating: activations/img92/output/output.csv
#   inflating: activations/img93/input.csv
#   inflating: activations/img93/output.csv
#   inflating: activations/img93/c1/input.csv
#   inflating: activations/img93/c1/output.csv
#   inflating: activations/img93/s2/input.csv
#   inflating: activations/img93/s2/output.csv
#   inflating: activations/img93/c3/input.csv
#   inflating: activations/img93/c3/output.csv
#   inflating: activations/img93/s4/input.csv
#   inflating: activations/img93/s4/output.csv
#   inflating: activations/img93/c5/input.csv
#   inflating: activations/img93/c5/output.csv
#   inflating: activations/img93/f6/input.csv
#   inflating: activations/img93/f6/output.csv
#   inflating: activations/img93/output/input.csv
#   inflating: activations/img93/output/output.csv
#   inflating: activations/img94/input.csv
#   inflating: activations/img94/output.csv
#   inflating: activations/img94/c1/input.csv
#   inflating: activations/img94/c1/output.csv
#   inflating: activations/img94/s2/input.csv
#   inflating: activations/img94/s2/output.csv
#   inflating: activations/img94/c3/input.csv
#   inflating: activations/img94/c3/output.csv
#   inflating: activations/img94/s4/input.csv
#   inflating: activations/img94/s4/output.csv
#   inflating: activations/img94/c5/input.csv
#   inflating: activations/img94/c5/output.csv
#   inflating: activations/img94/f6/input.csv
#   inflating: activations/img94/f6/output.csv
#   inflating: activations/img94/output/input.csv
#   inflating: activations/img94/output/output.csv
#   inflating: activations/img95/input.csv
#   inflating: activations/img95/output.csv
#   inflating: activations/img95/c1/input.csv
#   inflating: activations/img95/c1/output.csv
#   inflating: activations/img95/s2/input.csv
#   inflating: activations/img95/s2/output.csv
#   inflating: activations/img95/c3/input.csv
#   inflating: activations/img95/c3/output.csv
#   inflating: activations/img95/s4/input.csv
#   inflating: activations/img95/s4/output.csv
#   inflating: activations/img95/c5/input.csv
#   inflating: activations/img95/c5/output.csv
#   inflating: activations/img95/f6/input.csv
#   inflating: activations/img95/f6/output.csv
#   inflating: activations/img95/output/input.csv
#   inflating: activations/img95/output/output.csv
#   inflating: activations/img96/input.csv
#   inflating: activations/img96/output.csv
#   inflating: activations/img96/c1/input.csv
#   inflating: activations/img96/c1/output.csv
#   inflating: activations/img96/s2/input.csv
#   inflating: activations/img96/s2/output.csv
#   inflating: activations/img96/c3/input.csv
#   inflating: activations/img96/c3/output.csv
#   inflating: activations/img96/s4/input.csv
#   inflating: activations/img96/s4/output.csv
#   inflating: activations/img96/c5/input.csv
#   inflating: activations/img96/c5/output.csv
#   inflating: activations/img96/f6/input.csv
#   inflating: activations/img96/f6/output.csv
#   inflating: activations/img96/output/input.csv
#   inflating: activations/img96/output/output.csv
#   inflating: activations/img97/input.csv
#   inflating: activations/img97/output.csv
#   inflating: activations/img97/c1/input.csv
#   inflating: activations/img97/c1/output.csv
#   inflating: activations/img97/s2/input.csv
#   inflating: activations/img97/s2/output.csv
#   inflating: activations/img97/c3/input.csv
#   inflating: activations/img97/c3/output.csv
#   inflating: activations/img97/s4/input.csv
#   inflating: activations/img97/s4/output.csv
#   inflating: activations/img97/c5/input.csv
#   inflating: activations/img97/c5/output.csv
#   inflating: activations/img97/f6/input.csv
#   inflating: activations/img97/f6/output.csv
#   inflating: activations/img97/output/input.csv
#   inflating: activations/img97/output/output.csv
#   inflating: activations/img98/input.csv
#   inflating: activations/img98/output.csv
#   inflating: activations/img98/c1/input.csv
#   inflating: activations/img98/c1/output.csv
#   inflating: activations/img98/s2/input.csv
#   inflating: activations/img98/s2/output.csv
#   inflating: activations/img98/c3/input.csv
#   inflating: activations/img98/c3/output.csv
#   inflating: activations/img98/s4/input.csv
#   inflating: activations/img98/s4/output.csv
#   inflating: activations/img98/c5/input.csv
#   inflating: activations/img98/c5/output.csv
#   inflating: activations/img98/f6/input.csv
#   inflating: activations/img98/f6/output.csv
#   inflating: activations/img98/output/input.csv
#   inflating: activations/img98/output/output.csv
#   inflating: activations/img99/input.csv
#   inflating: activations/img99/output.csv
#   inflating: activations/img99/c1/input.csv
#   inflating: activations/img99/c1/output.csv
#   inflating: activations/img99/s2/input.csv
#   inflating: activations/img99/s2/output.csv
#   inflating: activations/img99/c3/input.csv
#   inflating: activations/img99/c3/output.csv
#   inflating: activations/img99/s4/input.csv
#   inflating: activations/img99/s4/output.csv
#   inflating: activations/img99/c5/input.csv
#   inflating: activations/img99/c5/output.csv
#   inflating: activations/img99/f6/input.csv
#   inflating: activations/img99/f6/output.csv
#   inflating: activations/img99/output/input.csv
#   inflating: activations/img99/output/output.csv
#   inflating: weights/c1.conv.weight.csv
#   inflating: weights/c3.conv.weight.csv
#   inflating: weights/c5.conv.weight.csv
#   inflating: weights/f6.fc.weight.csv
#   inflating: weights/output.fc.weight.csv
#   inflating: weights/output.fc.bias.csv
#   inflating: scale.json
#   inflating: scale_hw.json

# %%
import unittest
import nnunittest

suite = unittest.TestLoader().loadTestsFromTestCase(nnunittest.OpTestCase)
#suite = unittest.TestLoader().loadTestsFromTestCase(OpTestCase)
unittest.TextTestRunner(verbosity=2).run(suite)
# Out:
# test_C1 (nnunittest.OpTestCase) ... ok
# test_C3 (nnunittest.OpTestCase) ... ok
# test_C5 (nnunittest.OpTestCase) ... ok
# test_F6 (nnunittest.OpTestCase) ... ok
# test_OUTPUT (nnunittest.OpTestCase) ... ok
# test_S2 (nnunittest.OpTestCase) ... ok
# test_S4 (nnunittest.OpTestCase) ... ok
# test_edges (nnunittest.OpTestCase) ... ok
#
# ----------------------------------------------------------------------
# Ran 8 tests in 25.980s
#
# OK
# <unittest.runner.TextTestResult run=8 errors=0 failures=0>

# %% [markdown]
# ### 1.2 Reconstruct the LeNet in HW1
# * Fill in the TODO in `forward()` of `LeNet`.
# * Test the model with the test dataset. There should be no accuracy degradation if you have done everything correctly.

# %%
from nnutils import LeNet
import nnutils.test as test
import torch
import torchvision
import torchvision.transforms as transforms

transform = transforms.Compose(
    [
     transforms.Resize((32, 32)),
     transforms.ToTensor(),
     transforms.Normalize((0.5,), (0.5,))
    ])

testset = torchvision.datasets.MNIST(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=4,
                                         shuffle=False, num_workers=2)

def run_LeNet(n_bit, max_samples = None):
    number_range = (-(2**(n_bit-1)), 2**(n_bit-1) - 1)
    print("bit:", n_bit)
    print("bit-width range:",number_range)

    psum_range = {
        'c1': number_range,
        'c3': number_range,
        'c5': number_range,
        'f6': number_range,
        'output': number_range
    }

    model = LeNet(psum_range)

    return test(model, testloader)

run_LeNet(n_bit = 32)
# Out:
# bit: 32
# bit-width range: (-2147483648, 2147483647)
# Accuracy: 98.13%
# 98.13

# %% [markdown]
# ## 2. Bit-width of Partial Sums
# ### 2.1 Question: Find the minimum bit-width of partial sums for all layers with the highest accuracy
# 1. Use matplotlib to plot "Test Accuracy(%)" versus "Bit-width of Partial Sums" for "Bit-width of Partial Sums" in $[2, 32]$ by `matplotlib.pyplot.plot()`.
#     * [Plot with matplotlib](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html).
# 2. What is the smallest bit-width of partial sums that maintains the same accuracy from the previous plot?

# %% [markdown]
# ### 2.1 Answers
# <font color='red'>Write your answers here.</font>
# 1. 如下方程式執行完後輸出的圖
# 2. 18-bits 是最少且可以維持在跟 32-bits 一樣高 Accuracy(98.13%) 的bit數。

# %%
import matplotlib.pyplot as plt
acc = []
for i in range(1, 17):
    acc.append(run_LeNet(i*2))

# TODO
plt.xlabel("Bit-width of Partial Sums")
plt.ylabel("Test Accuracy(%)")
plt.title("Test Accuracy(%) v.s. Bit-width of Partial Sums")
plt.plot(range(2,34,2),acc)
plt.show()
# Out:
# bit: 2
# bit-width range: (-2, 1)
# Accuracy: 9.8%
# bit: 4
# bit-width range: (-8, 7)
# Accuracy: 9.8%
# bit: 6
# bit-width range: (-32, 31)
# Accuracy: 9.8%
# bit: 8
# bit-width range: (-128, 127)
# Accuracy: 9.8%
# bit: 10
# bit-width range: (-512, 511)
# Accuracy: 9.8%
# bit: 12
# bit-width range: (-2048, 2047)
# Accuracy: 9.8%
# bit: 14
# bit-width range: (-8192, 8191)
# Accuracy: 13.139999999999999%
# bit: 16
# bit-width range: (-32768, 32767)
# Accuracy: 95.25%
# bit: 18
# bit-width range: (-131072, 131071)
# Accuracy: 98.13%
# bit: 20
# bit-width range: (-524288, 524287)
# Accuracy: 98.13%
# bit: 22
# bit-width range: (-2097152, 2097151)
# Accuracy: 98.13%
# bit: 24
# bit-width range: (-8388608, 8388607)
# Accuracy: 98.13%
# bit: 26
# bit-width range: (-33554432, 33554431)
# Accuracy: 98.13%
# bit: 28
# bit-width range: (-134217728, 134217727)
# Accuracy: 98.13%
# bit: 30
# bit-width range: (-536870912, 536870911)
# Accuracy: 98.13%
# bit: 32
# bit-width range: (-2147483648, 2147483647)
# Accuracy: 98.13%

# %% [markdown]
# ### 2.2 Question: Find the minimum bit-width of partial sums for each layer with the highest accuracy
# 1. Plot the distribution of partial sums of each quantized layer in the CNN with the MNIST test dataset. Write down the min, max, and standard deviation for each layer.
#     * Check the TODO in `LeNet` of `LeNetModel`. You should save all partial sums to the dictionary, `psum_record_dict`.
#     * We can get this dictionary after running the model with the first image in the test dataset by `model.psum_record_dict`.
# 2. Determine the minimum bit-width of partial sums in each layer without hurting the accuracy.
#     * Fill in the TODO to see if the accuracy is still the same.
#     * Show the accuracy after doing so.

# %% [markdown]
# ### 2.2 Answers
# <font color='red'>Write your answers here.</font>
# 1. Layer: c1
#
#        max: 90890
#        min: -87663
#        standard-deviation: 20342.48140778911
#
#    Layer: c3
#        max: 45015
#        min: -103454
#        standard-deviation: 15670.133818757799
#
#    Layer: c5
#        max: 56490
#        min: -88113
#        standard-deviation: 18553.87846727538
#
#    Layer: f6
#        max: 35653
#        min: -49392
#        standard-deviation: 11948.112733686756
#
#    Layer: output
#        max: 7338
#        min: -36733
#        standard-deviation: 8776.06021218824
#
# 2. TODO 程式碼如下。最後算出來的結果，每一層的 partial sum 需要至少18bits 來維持一樣的Accuracy，結果會在下方code執行完時印出來。Accuracy一樣是98.13%。

# %%
import numpy as np
import matplotlib.pyplot as plt
n_bit = 32
number_range = (-(2**(n_bit-1)), 2**(n_bit-1) - 1)
print("bit:", n_bit)
print("bit-width range:",number_range)

psum_range = {
    'c1': number_range,
    'c3': number_range,
    'c5': number_range,
    'f6': number_range,
    'output': number_range
}

model = LeNet(psum_range)

image = np.expand_dims(testset[0][0], axis=0)
_ = model.forward(image, psum_record = True)

# TODO
# Plot the distribution of partial sums of each quantized layer in the CNN
for i in model.psum_record_dict:
    plt.hist(model.psum_record_dict[i])
    plt.ylabel("amount")
    plt.xlabel("number-range")
    plt.title(i)
    plt.show()
    print("Layer:", i)
    print("max:",max(model.psum_record_dict[i]))
    print("min:",min(model.psum_record_dict[i]))
    print("standard-deviation:",np.std(model.psum_record_dict[i]))
    print("\n")
# Out:
# bit: 32
# bit-width range: (-2147483648, 2147483647)
# Layer: c1
# max: 90890
# min: -87663
# standard-deviation: 20342.48140778911
# Layer: c3
# max: 45015
# min: -103454
# standard-deviation: 15670.133818757799
# Layer: c5
# max: 56490
# min: -88113
# standard-deviation: 18553.87846727538
# Layer: f6
# max: 35653
# min: -49392
# standard-deviation: 11948.112733686756
# Layer: output
# max: 7338
# min: -36733
# standard-deviation: 8776.06021218824

# %%
# TODO
# Test your model with those Bit-widths you choose

n_bit_each_layer = {}

psum_range = {}

for key in model.psum_record_dict:
    for i in range(2,34,2):
        n_bit = i
        number_range = (-(2**(n_bit-1)), 2**(n_bit-1) - 1)
        if (max(model.psum_record_dict[key]) > number_range[1]) or (min(model.psum_record_dict[key]) < number_range[0]):
            continue
        else:
            n_bit_each_layer[key] = n_bit
            psum_range[key] = number_range
            print("Layer:", key)
            print("bit:", n_bit)
            print("bit-width range:",number_range)
            break

model = LeNet(psum_range)

_ = test(model, testloader)
# Out:
# Layer: c1
# bit: 18
# bit-width range: (-131072, 131071)
# Layer: c3
# bit: 18
# bit-width range: (-131072, 131071)
# Layer: c5
# bit: 18
# bit-width range: (-131072, 131071)
# Layer: f6
# bit: 18
# bit-width range: (-131072, 131071)
# Layer: output
# bit: 18
# bit-width range: (-131072, 131071)
# Accuracy: 98.13%

# %% [markdown]
# ## 3. Evaluation: Energy Model
# ### 3.1 Question: Evaluate these two approaches based on the following energy model:
# $$E_w = s_{mul}\times N_{mul} + s_{add}\times N_{add}$$
# $$s_{mul} = 64\times \left(\frac{B_{mul}}{8}\right)^2, s_{add} = B_{add}$$
# where $N_{mul}$ and $N_{add}$ are the number of multiplications and additions, respectively. $B_{mul}$ and $B_{add}$ are the bit-widths of multiplier and adder, respectively. $s_{mul}$ denotes the power scaling factor of multiplication; $s_{add}$ denotes the power scaling factor of addition.
# * You must accumulate the energy layer by layer to obtain the overall $E_w$, if each layer has a  different $B_{mul}$ or $B_{add}$.
# * We only consider convolution and fully-connected operations, ignoring pooling and ReLU operations in this energy model.
# * Disclaimer: Note that this energy model is artificial and oversimplified. DO NOT apply it to your research work.
#
# 1. Calculate the overall $E_w$ for the setup of 2.1.
# 2. Calculate the energy layer by layer and also the overall $E_w$ for the setup of 2.2.

# %% [markdown]
# ### 3.1 Answers
# <font color='red'>Write your answers here.</font>
#
# layer c1 :
#
#     mul 28 * 28 * 6 * 25 = 117600
#     add 28 * 28 * 6 * 25 = 117600
#
# layer c3 :
#
#     mul 10 * 10 * 6 * 25 * 16 = 240000
#     add 10 * 10 * 6 * 25 * 16 = 240000
#
# layer c5 :
#
#     mul 120 * 25 * 16 = 48000
#     add 120 * 25 * 16 = 48000
#
# layer f6 :
#
#     mul 120 * 84 = 10080
#     add 120 * 84 = 10080
#
# layer out :
#
#     mul 84 * 10 = 840
#     add 84 * 10 + 10 = 850
#
# $N_{mul} = 117600+240000+48000+10080+840 = 416,520$
#
# $N_{add} = 117600+240000+48000+10080+850 = 416,530$
#
#
# 1. $s_{mul} = 64\times \left(\frac{32}{8}\right)^2 = 1024$
#
#    $s_{add} = 32$
#
#    $E_w = s_{mul}\times N_{mul} + s_{add}\times N_{add} = 1024 * 416520 + 32 * 416530 = 439,845,440$
#
#
# 2. $s_{mul} = 64\times \left(\frac{18}{8}\right)^2 = 324$
#
#    $s_{add} = 18$
#
#    $E_w = s_{mul}\times N_{mul} + s_{add}\times N_{add} = 324 * 416520 + 18 * 416530 = 142,450,020$
